# %% [markdown]
# # Yolov4 Pytorch 1.7 for Edge Devices with Amazon SageMaker
#
#
# Amazon SageMaker is a fully managed machine learning service. With SageMaker, data scientists and developers can quickly and easily build and train machine learning models, and then directly deploy them into a production-ready hosted environment. It provides an integrated Jupyter authoring notebook instance for easy access to your data sources for exploration and analysis, so you don't have to manage servers. It also provides common machine learning algorithms that are optimized to run efficiently against extremely large data in a distributed environment. With native support for bring-your-own-algorithms and frameworks, SageMaker offers flexible distributed training options that adjust to your specific workflows.
#
# SageMaker also offers capabilities to prepare models for deployment at the edge. [SageMaker Neo](https://docs.aws.amazon.com/sagemaker/latest/dg/neo.html) is a capability of Amazon SageMaker that enables machine learning models to train once and run anywhere in the cloud and at the edge and [Amazon SageMaker Edge Manager](https://docs.aws.amazon.com/sagemaker/latest/dg/edge.html) provides model management for edge devices so you can optimize, secure, monitor, and maintain machine learning models on fleets of edge devices such as smart cameras, robots, personal computers, and mobile devices.
#
#
# In this notebook we'll train a [**Yolov4**](https://github.com/WongKinYiu/PyTorch_YOLOv4) model on Pytorch using Amazon SageMaker to draw bounding boxes around images and then, compile and package it so that it can be deployed on an edge device(in this case, a [Jetson Xavier](https://developer.nvidia.com/jetpack-sdk-441-archive)).

# %% [markdown]
# ## 1) Pre-requisites
#
# Let us start with setting up the pre-requisites for this notebook. First, we will sagemaker and other related libs and then set up the role and buckets and some variables. Note that, we are also specifying the size of the image and also the model size taken as Yolov4s where s stand for small. Check out the [github doc of yolov4](https://github.com/WongKinYiu/PyTorch_YOLOv4) to understand how model sizes differ.

# %%
import sagemaker
import numpy as np
import glob
import os
from sagemaker.pytorch.estimator import PyTorch

from matplotlib import pyplot as plt  # for image display
import matplotlib.patches as patches  # for image display
from PIL import Image as pil_image    # PIL is the Python Imaging Library for image display
import random                         # for image display
from pathlib import Path              # for image display

role = sagemaker.get_execution_role()
sagemaker_session=sagemaker.Session()
bucket_name = sagemaker_session.default_bucket()
img_size= 416 #reset to 416
model_type='tiny' # tiny or ''
model_name='yolov4'if model_type=='' else f"yolov4-{model_type}"
# Out:
# Couldn't call 'get_role' to get Role ARN from role name AmazonSageMaker-ExecutionRole-20220616T175296 to get Role path.
# Assuming role was created in SageMaker AWS console, as the name contains `AmazonSageMaker-ExecutionRole`. Defaulting to Role ARN with service-role in path. If this Role ARN is incorrect, please add IAM read permissions to your role or supply the Role Arn directly.

# %% [markdown]
# ### 1.2) Image display constants

# %%
image_path = '/root/RI_Industry_Kit/cv-model/coco128/augmented_train/'
image_extension = '.jpg'
label_path = '/root/RI_Industry_Kit/cv-model/coco128/augmented_train_labels/'
label_extension = '.txt'

# %% [markdown]
# ### 1.3) Function to display image with all bounding boxes

# %%
def display_image_with_bounding_boxes (image, boxes):
    # function to display an image with its bounding boxes
    #
    # image is a Python Image Library image object holding image
    # boxes is a np.array holding bounding boxes
    #    in COCO format bounding box annotation
    #    [class, x_center, y_center, width, height]
    #    in dimensions as a fraction of the whole

    def add_bounding_box_to_image (axis, box, width, height):
        # function to add a single bounding box to an image
        #
        # axis is MatLibPlot axis object
        # box is np array holding dimensions for a single bounding box
        #    in COCO format bounding box annotation
        #    [class, x_center, y_center, width, height]
        #    in dimensions as a fraction of the whole
        # width is image width in pixels
        # height is image height in pixels
        
        # Create a Rectangle patch for the box
        
        if box[0] == 0:
            rect = patches.Rectangle(((box[1]-box[3]/2)*width, (box[2]-box[4]/2)*height),
                                 box[3]*width,
                                 box[4]*height,
                                 edgecolor='r',
                                 facecolor='none')
       
        elif box[0]==1: 
            rect = patches.Rectangle(((box[1]-box[3]/2)*width, (box[2]-box[4]/2)*height),
                                 box[3]*width,
                                 box[4]*height,
                                 edgecolor='y',
                                 facecolor='none')
        axis.add_patch(rect)
        
        
        
    # get image width & height
    width, height = image.size

    # Create the figure and axis
    fig, ax = plt.subplots()
    
    # set the image
    ax.imshow(np.array(image))    # convert image to np.array for use by MatLibPlot imshow
    
    # loop through boxes to add each bounding box to the image
    # get number of boxes
    number_of_boxes = boxes.shape[0]    # index 0 returns first dimension, index 1 returns second dimension, etc.
    for counter in range(number_of_boxes):    # loops from 0 to (number_of_boxes - 1)
        # get a single box from boxes
        box = boxes [counter]
        # add the bounding box to the image
        add_bounding_box_to_image (ax, box, width, height)
    
    # show the image with the bounding boxes
    plt.show()

# %% [markdown]
# ## 2.4) Data engineering (inspection, preparation, and analysis)

# %% [markdown]
# Lets look at the label format used for the dataset. It should follow the same standard as COCO.
#
# If you need an example of the COCO format standard, a sample dataset is available [coco128](https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip). Use this code to download it.
# '''
#
# if not os.path.exists('coco128'):
#     !wget -q https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip
#     !unzip -q coco128.zip && rm -f coco128.zip

# %%
os.chdir("/root/RI_Industry_Kit/cv-model/")
print('BBoxes annotation')
print('class x_center y_center width height')
# !head ./coco128/augmented_train_labels/0_1-18_thermal_cropped0_jpg.rf.51c6e2732d21dc222839971c7e10abd6.txt
# Out:
# BBoxes annotation
# class x_center y_center width height
# 0 0.375 0.35216346153846156 0.020432692307692308 0.018028846153846152
# 0 0.08052884615384616 0.4951923076923077 0.016826923076923076 0.016826923076923076
# 0 0.40625 0.35216346153846156 0.018028846153846152 0.020432692307692308
# 0 0.4375 0.35216346153846156 0.020432692307692308 0.016826923076923076
# 0 0.19471153846153846 0.4987980769230769 0.02403846153846154 0.021634615384615384
# 0 0.23317307692307693 0.4987980769230769 0.019230769230769232 0.018028846153846152
# 0 0.2704326923076923 0.5 0.020432692307692308 0.016826923076923076
# 0 0.30649038461538464 0.5 0.019230769230769232 0.018028846153846152
# 0 0.3473557692307692 0.5 0.019230769230769232 0.020432692307692308
# 0 0.11899038461538461 0.7199519230769231 0.016826923076923076 0.018028846153846152

# %% [markdown]
# #### 2.5) Randomly select five images and display them with there bounding boxes

# %%
print(label_path)
for counter in range(5):
    # randomly get a filename with extension but without the path
    image_filename = random.choice(os.listdir(image_path))
    # get the stem of the filename
    file_stem = Path(image_filename).stem
    print("stem", file_stem)
    image_file = image_path + file_stem + image_extension    # create the full path to the image 
    label_file = label_path + file_stem + label_extension    # create the full path to the bounding box labels for the image
    
    if Path(label_path + file_stem + label_extension).stat().st_size > 0:    # ignore if the labels are empty
        # image as a np.array holding image
        image = pil_image.open(image_file)
        # boxes as a np.array holding bounding boxes
        boxes = np.genfromtxt(label_file, delimiter=' ')
        display_image_with_bounding_boxes (image, boxes)
    else:
        print("... has no bounding box labels")
# Out:
# /root/RI_Industry_Kit/cv-model/coco128/augmented_train_labels/
# stem 2_3-0_thermal_cropped0_jpg.rf.24cad8f666e8e8b085715b914be1e481
# stem 0_1-10_thermal_cropped0_jpg.rf.973f23d1e1afc836a7fec143577268f2
# stem 2_3-1_thermal_cropped0_jpg.rf.4bb7b8f12615790cf9a583a41f4d6f1d
# stem 4-14_thermal_cropped0_jpg.rf.28d929ec57fb4b7fe650febbe7d923fa
# stem 2_3-18_thermal_cropped0_jpg.rf.07622da68e7ee30a19fc5eb6bec6e3b2

# %% [markdown]
# ## 2) Download a public implementation of Yolov4 for Pytorch (Author: Wong Kin Yiu)
#
# Now, we will download the PyTorch implementation of Yolov4 from this [repository](https://github.com/WongKinYiu/PyTorch_YOLOv4) which is authored by Wong Kin Yiu. We will place it in a local directory `yolov4`

# %%
if not os.path.isdir('yolov4'):
    # !git clone https://github.com/WongKinYiu/PyTorch_YOLOv4 yolov4
    # !cd yolov4 && git checkout 3c42cbd1b0fa28ad19436d01e0e240404463ff80 && git apply ../mish.patch
    # !echo 'tensorboard' > yolov4/requirements.txt

# %% [markdown]
# ## 2.1) Train the model by preparing a Python script that will be the entrypoint of the training process
#
# Now, we will create a training script to train the Yolov4 model. The training script will wrap the original training scripts and expose the parameters to SageMaker Estimator. The script accepts different arguments which will control the training process.

# %%
# %%writefile yolov4/sagemaker_train.py
import sys
import subprocess
## We need to remove smdebug to avoid the Hook bug https://github.com/awslabs/sagemaker-debugger/issues/401
subprocess.check_call([sys.executable, "-m", "pip", "uninstall", "-y", "smdebug"])
import os
import yaml
import argparse
import torch
import shutil
import urllib
import numpy as np
from models.models import Darknet
from utils.parse_config import parse_model_cfg

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    
    parser.add_argument('--num-classes', type=int, default=80, help='Number of classes')
    parser.add_argument('--img-size', type=int, default=640, help='Size of the image')
    parser.add_argument('--epochs', type=int, default=1, help='Number of epochs')
    parser.add_argument('--batch-size', type=int, default=16, help='Batch size')
    parser.add_argument('--adam', action='store_true', help='use torch.optim.Adam() optimizer')
    parser.add_argument('--pretrained', action='store_true', help='use pretrained model')
    
    parser.add_argument('--model-dir', type=str, default=os.environ["SM_MODEL_DIR"], help='Trained model dir')
    parser.add_argument('--train', type=str, default=os.environ["SM_CHANNEL_TRAIN"], help='Train path')
    parser.add_argument('--train-suffix', type=str, default='', help='Train path suffix')
    parser.add_argument('--validation', type=str, default=os.environ["SM_CHANNEL_VALIDATION"], help='Validation path')
    parser.add_argument('--validation-suffix', type=str, default='', help='Validation path suffix')
    
    parser.add_argument('--model-type', type=str, choices=['', 'tiny'], default="", help='Model type')
    
    # hyperparameters
    with open('data/hyp.scratch.yaml', 'r') as f:
        hyperparams = yaml.load(f, Loader=yaml.FullLoader)    
    for k,v in hyperparams.items():
        parser.add_argument(f"--{k.replace('_', '-')}", type=float, default=v)
    
    args,unknown = parser.parse_known_args()
    
    base_path=os.path.dirname(__file__)
    project_dir = os.environ["SM_OUTPUT_DATA_DIR"]

    # prepare the hyperparameters metadat
    with open(os.path.join(base_path,'data', 'hyp.custom.yaml'), 'w' ) as y:
        y.write(yaml.dump({h:vars(args)[h] for h in hyperparams.keys()}))

    # prepare the training data metadata
    with open(os.path.join(base_path,'data', 'custom.yaml'), 'w') as y:
        y.write(yaml.dump({            
            'names': [f'class_{i}' for i in range(args.num_classes)],
            'train': os.path.join(args.train, args.train_suffix),
            'val': os.path.join(args.validation, args.validation_suffix),
            'nc': args.num_classes
        }))

    model_name = "yolov4" if len(args.model_type) == 0 else f"yolov4-{args.model_type}"
    
    model_cfg_path = os.path.join(base_path, "cfg", f"{model_name}.cfg")
    model_params = parse_model_cfg(model_cfg_path)
    with open(model_cfg_path, 'w') as cfg:
        for p in model_params:
            if p['type'] == 'yolo':
                p['classes'] = args.num_classes
            elif p['type'] == 'convolutional' and p['filters'] == 255:
                p['filters'] = (args.num_classes + 5) * 3 # adjustment for the classes
            for k,v in p.items():
                if k=="type": cfg.write(f"[{v}]\n")
                else:
                    if type(v)==np.ndarray:
                        v = ','.join(str(i) for i in v.flatten().tolist())
                    elif type(v)==list:
                        v = ','.join(str(i) for i in v)
                    cfg.write(f"{k}={v}\n")
    
    # run the training script
    weights_file=''
    if args.pretrained:
        weights_file = f'weights/{model_name}.weights'
        urllib.request.urlretrieve(
            f'https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/{model_name}.weights',
            weights_file
        )
        
    train_cmd = [
        sys.executable, os.path.join(base_path,'train.py'),
        "--data", "custom.yaml",
        "--hyp", "hyp.custom.yaml",
        "--cfg", f"cfg/{model_name}.cfg",
        "--img", str(args.img_size),
        "--batch", str(args.batch_size),
        "--epochs", str(args.epochs),
        "--logdir", project_dir,
        "--weights", weights_file
    ]
    if args.adam: train_cmd.append("--adam")
    subprocess.check_call(train_cmd)
        
    # tracing and saving the model
    inp = torch.rand(1, 3, args.img_size, args.img_size).cpu()
    ckpt = torch.load(os.path.join(project_dir, 'exp0', 'weights', 'best.pt'), map_location='cpu')
    model = Darknet(f"cfg/{model_name}.cfg").cpu()
    # do not invoke .eval(). we don't need the detection layer
    model.load_state_dict(ckpt['model'], strict=False)
    p = model(inp)
    model_trace = torch.jit.trace(model, inp)
    model_trace.save(os.path.join(args.model_dir, 'model.pth'))
# Out:
# Overwriting yolov4/sagemaker_train.py

# %% [markdown]
# ### 2.1.2) Preparing the dataset
#
# Here we'll download a sample dataset [coco128](https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip). We can also replace this step with any other dataset.
#
# Just take a look on the labels format and create your dataset scructure following the same standard (COCO).

# %%
import os
#if not os.path.exists('coco128'):
#    !wget -q https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip
#    !unzip -q coco128.zip && rm -f coco128.zip
print('BBoxes annotation')
print('class x_center y_center width height')
# !head coco128/labels/augmented_train_labels/2_3-1_thermal_cropped0_jpg.rf.25de1e21c98feb0b49d34d58669a3434.txt
# Out:
# BBoxes annotation
# class x_center y_center width height
# head: cannot open 'coco128/labels/augmented_train_labels/2_3-1_thermal_cropped0_jpg.rf.25de1e21c98feb0b49d34d58669a3434.txt' for reading: No such file or directory

# %% [markdown]
# ### 2.1.3) Upload the dataset to S3
#
# Once the dataset has been downloaded locally, we'll upload the dataset to an S3 bucket created earlier. We are setting up the training and validation dataset s3 locations here.

# %%
prefix='data/coco128'
# !rm -f coco128/labels/train2017.cache
train_path = sagemaker_session.upload_data('coco128', key_prefix=f'{prefix}/train')
val_path = sagemaker_session.upload_data('coco128', key_prefix=f'{prefix}/val')
print(train_path, val_path)
# Out:
# s3://sagemaker-eu-west-1-009844909091/data/coco128/train s3://sagemaker-eu-west-1-009844909091/data/coco128/val

# %%
# !aws s3 rm --recursive s3://sagemaker-eu-west-1-009844909091/data/coco128/train/images/train2017/.ipynb_checkpoints
# !aws s3 rm --recursive s3://sagemaker-eu-west-1-009844909091/data/coco128/train/labels/train2017/.ipynb_checkpoints
# !aws s3 rm --recursive s3://sagemaker-eu-west-1-009844909091/data/coco128/val/images/train2017/.ipynb_checkpoints
# !aws s3 rm --recursive s3://sagemaker-eu-west-1-009844909091/data/coco128/val/labels/train2017/.ipynb_checkpoints

# %% [markdown]
# ### 2.1.4) Prepare the SageMaker Estimator to train the model
#
# Now it's time to create an Estimater and train the model with the training script created in earlier step. We are using Pytorch estimator and supplying other arguments in the estimator. Note that we are supplying the `source_dir` so that sagemaker can pick up the training script and other related files from there. Once the estimator is ready, we start the training using the `.fit()` method.

# %%
print(train_path, val_path)
# Out:
# s3://sagemaker-eu-west-1-009844909091/data/coco128/train s3://sagemaker-eu-west-1-009844909091/data/coco128/val

# %%
estimator = PyTorch(
    'sagemaker_train.py',
    source_dir='yolov4',
    framework_version='1.7',
    role=role,
    sagemaker_session=sagemaker_session, 
    instance_type='ml.g5.16xlarge',    
    instance_count=1,
    py_version='py3', 
    hyperparameters={
        'epochs': 2000, # at least 2 epochse
        'batch-size': 8,
        'lr0': 0.00001,
        
        'pretrained': False, # transfer learning
        'num-classes': 2,
        'img-size': img_size,
        'model-type': model_type,
        
        # the final path needs to point to the images dir
        'train-suffix': 'images/train2017',
        'validation-suffix': 'images/train2017'
    }
)

# %%
estimator.fit({'train': train_path, 'validation': val_path})
# Out:
# 2022-06-24 12:01:05 Starting - Starting the training job...
# 2022-06-24 12:01:32 Starting - Preparing the instances for trainingProfilerReport-1656072064: InProgress
# ......
# 2022-06-24 12:02:35 Downloading - Downloading input data...
# 2022-06-24 12:03:00 Training - Downloading the training image..................
# 2022-06-24 12:05:51 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-06-24 12:05:54,164 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-06-24 12:05:54,185 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-06-24 12:05:54,192 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-06-24 12:05:54,610 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.6 -m pip install -r requirements.txt
# Collecting tensorboard
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.6/site-packages (from tensorboard->-r requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.6/site-packages (from tensorboard->-r requirements.txt (line 1)) (49.6.0.post20210108)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.6/site-packages (from tensorboard->-r requirements.txt (line 1)) (1.19.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from tensorboard->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /opt/conda/lib/python3.6/site-packages (from tensorboard->-r requirements.txt (line 1)) (3.17.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.7-py3-none-any.whl (97 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.47.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.6/site-packages (from tensorboard->-r requirements.txt (line 1)) (0.35.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.8.0-py2.py3-none-any.whl (164 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 1)) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 1)) (4.7.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.8.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements.txt (line 1)) (3.10.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard->-r requirements.txt (line 1)) (1.25.11)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 1)) (0.8)
# Installing collected packages: pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, tensorboard-plugin-wit, tensorboard-data-server, markdown, grpcio, google-auth-oauthlib, absl-py, tensorboard
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.0.1
#     Uninstalling importlib-metadata-4.0.1:
#       Successfully uninstalled importlib-metadata-4.0.1
# Successfully installed absl-py-1.1.0 cachetools-4.2.4 google-auth-2.8.0 google-auth-oauthlib-0.4.6 grpcio-1.47.0 importlib-metadata-4.8.3 markdown-3.3.7 oauthlib-3.2.0 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# 2022-06-24 12:06:00,245 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 8,
#         "epochs": 2000,
#         "img-size": 416,
#         "lr0": 1e-05,
#         "model-type": "tiny",
#         "num-classes": 2,
#         "pretrained": false,
#         "train-suffix": "images/train2017",
#         "validation-suffix": "images/train2017"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2022-06-24-12-01-04-580",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-009844909091/pytorch-training-2022-06-24-12-01-04-580/source/sourcedir.tar.gz",
#     "module_name": "sagemaker_train",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g5.16xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g5.16xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "sagemaker_train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":8,"epochs":2000,"img-size":416,"lr0":1e-05,"model-type":"tiny","num-classes":2,"pretrained":false,"train-suffix":"images/train2017","validation-suffix":"images/train2017"}
# SM_USER_ENTRY_POINT=sagemaker_train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g5.16xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g5.16xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=sagemaker_train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-009844909091/pytorch-training-2022-06-24-12-01-04-580/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":8,"epochs":2000,"img-size":416,"lr0":1e-05,"model-type":"tiny","num-classes":2,"pretrained":false,"train-suffix":"images/train2017","validation-suffix":"images/train2017"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2022-06-24-12-01-04-580","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-009844909091/pytorch-training-2022-06-24-12-01-04-580/source/sourcedir.tar.gz","module_name":"sagemaker_train","network_interface_name":"eth0","num_cpus":64,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g5.16xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g5.16xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"sagemaker_train.py"}
# SM_USER_ARGS=["--batch-size","8","--epochs","2000","--img-size","416","--lr0","1e-05","--model-type","tiny","--num-classes","2","--pretrained","False","--train-suffix","images/train2017","--validation-suffix","images/train2017"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCH-SIZE=8
# SM_HP_EPOCHS=2000
# SM_HP_IMG-SIZE=416
# SM_HP_LR0=1e-05
# SM_HP_MODEL-TYPE=tiny
# SM_HP_NUM-CLASSES=2
# SM_HP_PRETRAINED=false
# SM_HP_TRAIN-SUFFIX=images/train2017
# SM_HP_VALIDATION-SUFFIX=images/train2017
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 sagemaker_train.py --batch-size 8 --epochs 2000 --img-size 416 --lr0 1e-05 --model-type tiny --num-classes 2 --pretrained False --train-suffix images/train2017 --validation-suffix images/train2017
# Found existing installation: smdebug 1.0.9
# Uninstalling smdebug-1.0.9:
#   Successfully uninstalled smdebug-1.0.9
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA A10G', total_memory=22731MB)
# Namespace(adam=False, batch_size=8, bucket='', cache_images=False, cfg='cfg/yolov4-tiny.cfg', data='./data/custom.yaml', device='', epochs=2000, evolve=False, global_rank=-1, hyp='./data/hyp.custom.yaml', img_size=[416, 416], local_rank=-1, logdir='/opt/ml/output/data', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=8, weights='weights/yolov4-tiny.weights', world_size=1)
# Start Tensorboard with "tensorboard --logdir /opt/ml/output/data", view at http://localhost:6006/
# Hyperparameters {'anchor_t': 4.0, 'cls': 0.5, 'cls_pw': 1.0, 'degrees': 0.0, 'fl_gamma': 0.0, 'fliplr': 0.5, 'flipud': 0.0, 'giou': 0.05, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'iou_t': 0.2, 'lr0': 1e-05, 'mixup': 0.0, 'momentum': 0.937, 'obj': 1.0, 'obj_pw': 1.0, 'perspective': 0.0, 'scale': 0.5, 'shear': 0.0, 'translate': 0.0, 'weight_decay': 0.0005}
# Model Summary: 61 layers, 5.87643e+06 parameters, 5.87643e+06 gradients
# Optimizer groups: 21 .bias, 21 conv.weight, 19 other
# Image sizes 416 train, 416 test
# Using 8 dataloader workers
# Starting training for 2000 epochs...
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0    0.000503    9.37e-05
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0      0.0011    0.000158
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00245    0.000328
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00376    0.000567
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00426    0.000719
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00483    0.000807
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00611     0.00101
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00613     0.00111
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00749     0.00129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0      0.0061    0.000745
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00516    0.000762
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00473    0.000749
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00494    0.000744
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00484    0.000737
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559         0.5     0.00279     0.00694    0.000892
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559         0.5     0.00279     0.00656     0.00081
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559         0.5     0.00279     0.00675    0.000826
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559         0.5     0.00279     0.00712    0.000839
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00522    0.000655
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00512    0.000704
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00466    0.000717
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00533    0.000869
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00528    0.000837
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00517    0.000818
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00558    0.000837
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00655       0.001
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00716     0.00111
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0      0.0066     0.00104
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0     0.00892      0.0013
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0      0.0113      0.0015
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559           0           0      0.0146     0.00176
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0606     0.00559      0.0137     0.00197
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.058      0.0168       0.013     0.00183
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0553      0.0223      0.0114     0.00157
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0415      0.0196      0.0162     0.00242
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0494      0.0223      0.0152     0.00213
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333      0.0168      0.0202     0.00279
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0392      0.0168      0.0226      0.0028
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0302      0.0112      0.0144       0.002
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0268      0.0112      0.0133     0.00231
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0398      0.0223      0.0126     0.00199
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0247      0.0168      0.0136     0.00195
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0345      0.0307      0.0139     0.00195
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0293      0.0363      0.0135     0.00186
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0418      0.0489      0.0138     0.00185
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336      0.0447      0.0143     0.00202
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0293      0.0503      0.0166     0.00276
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0243      0.0447      0.0142     0.00192
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0296      0.0419      0.0143     0.00184
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0267      0.0391      0.0131     0.00176
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0254      0.0391      0.0165     0.00231
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0207      0.0391      0.0141     0.00222
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0219      0.0559      0.0141     0.00196
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0166      0.0475      0.0103     0.00163
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.018      0.0475     0.00999      0.0015
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0254      0.0559      0.0115     0.00172
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0301      0.0587      0.0142      0.0019
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0317      0.0615      0.0124      0.0016
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.029      0.0559      0.0138      0.0018
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333      0.0587      0.0171     0.00218
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0286      0.0475      0.0154     0.00192
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0272      0.0503      0.0145     0.00186
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0299      0.0587      0.0134     0.00186
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.031      0.0615       0.012      0.0017
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0267      0.0615      0.0176     0.00253
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0293      0.0698      0.0166     0.00245
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0272      0.0615      0.0144     0.00237
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0265      0.0559      0.0148     0.00228
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0318      0.0587       0.013     0.00194
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0286      0.0503      0.0133     0.00194
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0382      0.0698      0.0149     0.00218
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0323      0.0642      0.0151     0.00204
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0292      0.0726      0.0153     0.00245
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0264      0.0726      0.0155     0.00245
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0276      0.0838      0.0167     0.00253
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0292      0.0922      0.0172     0.00229
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.026      0.0838      0.0141     0.00202
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.026      0.0894      0.0148     0.00206
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0266      0.0894      0.0155     0.00223
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0269      0.0894      0.0152     0.00212
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0249      0.0782      0.0193     0.00245
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0236      0.0754      0.0184     0.00234
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0243      0.0782      0.0168     0.00221
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.027      0.0926      0.0169     0.00222
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0272      0.0978      0.0172     0.00225
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0256      0.0894      0.0156     0.00227
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0244      0.0866      0.0145     0.00215
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0275       0.101      0.0153     0.00231
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0274       0.106      0.0151     0.00222
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0269       0.109      0.0151     0.00223
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0228      0.0978      0.0146     0.00218
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0247       0.109      0.0153     0.00232
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0265        0.12      0.0198     0.00277
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0311        0.14      0.0226     0.00313
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0292       0.134      0.0201       0.003
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0302       0.142      0.0193     0.00274
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0326       0.148       0.021     0.00289
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0315        0.14      0.0212     0.00317
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0304       0.134      0.0169     0.00251
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0299       0.131      0.0186     0.00269
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0301       0.128      0.0188     0.00278
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0247       0.109      0.0163     0.00261
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.024       0.109      0.0166     0.00255
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0253        0.12      0.0182     0.00279
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0238       0.117      0.0163     0.00248
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0231       0.115      0.0164     0.00246
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0219       0.115      0.0147     0.00216
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0219       0.115      0.0147     0.00216
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0217       0.117      0.0145     0.00209
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0216        0.12      0.0133     0.00185
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0208        0.12      0.0126     0.00177
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0203        0.12      0.0121     0.00165
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0204       0.125      0.0127     0.00167
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0188       0.117      0.0121     0.00159
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0181       0.115      0.0109     0.00151
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0196       0.126      0.0124     0.00171
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0207       0.137      0.0133      0.0018
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0202       0.137      0.0133     0.00171
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0213       0.148      0.0138     0.00179
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0205       0.142      0.0128     0.00165
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0204       0.142       0.013     0.00165
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0195       0.137      0.0124     0.00151
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0194       0.137      0.0119     0.00155
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0196        0.14      0.0128     0.00159
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0191       0.137      0.0118     0.00154
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0201       0.142       0.013     0.00164
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0201        0.14      0.0132     0.00164
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0197       0.137       0.013      0.0016
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0211       0.145      0.0134     0.00162
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.021       0.145      0.0128     0.00157
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0185       0.126      0.0114     0.00145
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0207       0.134      0.0122     0.00155
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0207       0.134      0.0122     0.00155
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0224       0.142      0.0137     0.00173
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0225        0.14      0.0136     0.00184
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0226       0.137      0.0142     0.00195
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0218       0.128      0.0145     0.00201
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0255       0.145      0.0172     0.00215
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0268       0.145       0.017     0.00212
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0268       0.145       0.017     0.00212
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0297       0.154      0.0198     0.00254
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.029       0.148      0.0196     0.00261
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0287       0.142      0.0187     0.00258
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0289       0.142      0.0196     0.00257
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0279        0.14      0.0189     0.00258
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0273       0.134      0.0188     0.00253
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0273       0.134      0.0188     0.00253
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0262       0.131      0.0181     0.00247
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.025       0.128      0.0173     0.00232
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0265        0.14      0.0172     0.00241
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0252        0.14      0.0169     0.00238
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0282       0.156      0.0198      0.0027
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.027       0.156       0.019     0.00248
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.027       0.156       0.019     0.00248
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0255       0.156      0.0184     0.00239
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0255       0.156      0.0184     0.00239
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0241       0.154      0.0169      0.0022
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0237       0.154      0.0162     0.00225
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0227       0.154      0.0166     0.00228
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0227       0.154      0.0166     0.00228
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0238       0.162      0.0164     0.00234
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0222       0.156      0.0158     0.00216
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0211       0.154      0.0158       0.002
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0211       0.154      0.0158       0.002
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0207       0.148      0.0151     0.00221
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.022       0.154       0.016     0.00235
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.023       0.159      0.0154     0.00217
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.023       0.159      0.0154     0.00217
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0241       0.159      0.0165     0.00245
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.026        0.17      0.0172     0.00251
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0265       0.179      0.0172     0.00253
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0265       0.179      0.0172     0.00253
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0263       0.182      0.0176     0.00243
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0264       0.184      0.0198     0.00262
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0271        0.19      0.0205     0.00277
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0271        0.19      0.0205     0.00277
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0267        0.19      0.0204     0.00273
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.025       0.176      0.0181     0.00254
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.024       0.173      0.0175     0.00247
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.024       0.173      0.0175     0.00247
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0238       0.173       0.018     0.00258
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0234       0.173      0.0176     0.00266
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0247       0.187      0.0187     0.00261
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0247       0.187      0.0187     0.00261
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0244        0.19       0.019     0.00259
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0238       0.184      0.0189     0.00271
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0243       0.187      0.0189     0.00258
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0243       0.187      0.0189     0.00258
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.023       0.179      0.0171      0.0025
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0236       0.184      0.0178     0.00276
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0246       0.193      0.0186     0.00292
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0246       0.193      0.0186     0.00292
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0234       0.184      0.0163     0.00256
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0257       0.193      0.0196      0.0028
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0281       0.196      0.0201     0.00261
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0281       0.196      0.0201     0.00261
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0287       0.201      0.0202     0.00264
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0271       0.193      0.0201     0.00273
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
# ...
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0325       0.268        0.07      0.0129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0331       0.274      0.0725      0.0132
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333       0.274      0.0734      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333       0.274      0.0734      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0334       0.274      0.0734      0.0135
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336       0.271      0.0732      0.0131
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0348       0.282      0.0728      0.0131
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0348       0.282      0.0728      0.0131
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337       0.271      0.0713      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0338       0.265      0.0723      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336       0.262      0.0715      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336       0.262      0.0715      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0323       0.246      0.0692      0.0135
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0325       0.246      0.0685      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0326       0.249      0.0629       0.013
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0326       0.249      0.0629       0.013
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0341       0.257      0.0669      0.0128
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337       0.254      0.0671       0.013
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333       0.257      0.0699      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333       0.257      0.0699      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0341       0.263      0.0628      0.0131
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.033       0.257      0.0647      0.0129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0332        0.26      0.0646      0.0128
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0332        0.26      0.0646      0.0128
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0328       0.257      0.0631      0.0128
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0349       0.271      0.0639      0.0128
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0347       0.268      0.0673      0.0135
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0347       0.268      0.0673      0.0135
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0335       0.263      0.0653      0.0126
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336       0.263       0.062      0.0123
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0332        0.26      0.0631      0.0124
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0332        0.26      0.0631      0.0124
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0331       0.257      0.0629      0.0122
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336        0.26      0.0693       0.013
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0323       0.249      0.0721       0.014
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0323       0.249      0.0721       0.014
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0336        0.26      0.0648      0.0128
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0328       0.254      0.0689      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0334        0.26      0.0711      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0334        0.26      0.0711      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337       0.263      0.0645      0.0126
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0319       0.257      0.0652      0.0129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0311       0.254      0.0652      0.0126
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0311       0.254      0.0652      0.0126
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0299       0.251      0.0641      0.0125
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0297       0.249      0.0602      0.0124
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0309        0.26      0.0657      0.0127
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0309        0.26      0.0657      0.0127
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0313        0.26      0.0666      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0331       0.271      0.0678      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0318        0.26      0.0683      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0318        0.26      0.0683      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0313       0.251      0.0649      0.0131
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0315       0.246      0.0607      0.0129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0319       0.245      0.0629      0.0129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0319       0.245      0.0629      0.0129
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0318       0.246      0.0649      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337        0.26      0.0714      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0328       0.257      0.0721      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0328       0.257      0.0721      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0341       0.268      0.0806      0.0145
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0331        0.26      0.0727      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337       0.265      0.0682      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337       0.265      0.0682      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333       0.263      0.0667      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0321       0.249      0.0716      0.0143
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0329       0.254      0.0697      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0329       0.254      0.0697      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0332       0.255      0.0704      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0344       0.268      0.0697      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0327        0.26      0.0699      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0327        0.26      0.0699      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0337       0.265      0.0717      0.0134
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0332       0.265      0.0702      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0324       0.257      0.0709      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0324       0.257      0.0709      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.033       0.263        0.07      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0331       0.263      0.0709      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.032       0.255      0.0673      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559       0.032       0.255      0.0673      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0318       0.254      0.0672      0.0135
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0331       0.263      0.0737       0.014
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0335       0.263      0.0722       0.014
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0335       0.263      0.0722       0.014
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0334        0.26      0.0704      0.0138
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0333        0.26       0.069      0.0137
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0355       0.271      0.0691      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0355       0.271      0.0691      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0349       0.263      0.0647      0.0133
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0352       0.263      0.0652      0.0136
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#                  all          43         559      0.0356       0.257      0.0638      0.0131
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size

# %%
s3_uri=f'{estimator.output_path}{estimator.latest_training_job.name}/output/model.tar.gz'
print('trained model: ' + s3_uri )
# Out:
# trained model: s3://sagemaker-eu-west-1-009844909091/pytorch-training-2022-06-24-12-01-04-580/output/model.tar.gz

# %% [markdown]
# ## 4) Compile your trained model for the edge device
#
# Once the model has been traied, we need to compile the model using SageMaker Neo. This step is needed to compile the model for the specific hardware on which this model will be deployed.
#
# In this notebook, we will compile a model for [Jetson Xavier Jetpack 4.4.1](https://developer.nvidia.com/jetpack-sdk-441-archive).
#
# In case, you want to compile for a different hardware platform, just change the parameters bellow to adjust the target to your own edge device. Also, note, that if you dont have GPU available on the hardware device, then you can comment the `Accelerator` key:value in the `OutputConfig`.
#
# The below cell also calls the `describe_compilation_job` API in a loop to wait for the compilation job to complete. In actual applications, it is advisable to setup a cloudwatch event which can notify OR execute the next steps once the compilation job is complete.

# %%
import time
import boto3
sm_client = boto3.client('sagemaker')
compilation_job_name = f'{model_name}-pytorch-{int(time.time()*1000)}'
sm_client.create_compilation_job(
    CompilationJobName=compilation_job_name,
    RoleArn=role,
    InputConfig={
        'S3Uri': s3_uri,
        'DataInputConfig': f'{{"input": [1,3,{img_size},{img_size}]}}',
        'Framework': 'PYTORCH'
    },
    OutputConfig={
        'S3OutputLocation': f's3://{sagemaker_session.default_bucket()}/{model_name}-pytorch/optimized/',
        'TargetPlatform': { 
            'Os': 'LINUX', 
            'Arch': 'X86_64'#, # change this to X86_64 if you need
            #'Arch': 'ARM64', # change this to X86_64 if you need
            #'Accelerator': 'NVIDIA'  # comment this if you don't have an Nvidia GPU
        }#,
        # Comment or change the following line depending on your edge device
        # Jetson Xavier: sm_72; Jetson Nano: sm_53
        #'CompilerOptions': '{"trt-ver": "7.1.3", "cuda-ver": "10.2", "gpu-code": "sm_53"}' # Jetpack 4.4.1
    },
    StoppingCondition={ 'MaxRuntimeInSeconds': 900 }
)
while True:
    resp = sm_client.describe_compilation_job(CompilationJobName=compilation_job_name)    
    if resp['CompilationJobStatus'] in ['STARTING', 'INPROGRESS']:
        print('Running...')
    else:
        print(resp['CompilationJobStatus'], compilation_job_name)
        break
    time.sleep(5)
# Out:
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# Running...
# COMPLETED yolov4-tiny-pytorch-1656077502079

# %% [markdown]
# ## 5) Download the compiled model

# %%
#!wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

# %%
# tracing and saving the model
#import torch
#inp = torch.rand(1, 3, 416, 416).cpu()
#ckpt = torch.load("yolov4-tiny.weights", map_location='cpu')
#model = Darknet(f"yolov4/cfg/{model_name}.cfg").cpu()
# do not invoke .eval(). we don't need the detection layer
#model.load_state_dict(ckpt['model'], strict=False)
#p = model(inp)
#model_trace = torch.jit.trace(model, inp)
#model_trace.save('model.pth')

# %%
output_model_path = f's3://{sagemaker_session.default_bucket()}/{model_name}-pytorch/optimized/model-LINUX_X86_64.tar.gz'

# !aws s3 cp $output_model_path /tmp/model.tar.gz
# !rm -rf model_object_detection && mkdir model_object_detection
# !tar -xzvf /tmp/model.tar.gz -C model_object_detection
# Out:
# download: s3://sagemaker-eu-west-1-009844909091/yolov4-tiny-pytorch/optimized/model-LINUX_X86_64.tar.gz to ../../../tmp/model.tar.gz
# dlr.h
# compiled.meta
# compiled.so
# compiled.params
# compiled_model.json
# libdlr.so
# manifest

# %% [markdown]
# ## 6) Run the model locally

# %%
# %matplotlib inline
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### 6.1) Load the model using the runtime DLR

# %%
# !pip install dlr==1.8.0
# Out:
# Collecting dlr==1.8.0
#   Using cached dlr-1.8.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from dlr==1.8.0) (1.19.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from dlr==1.8.0) (2.25.1)
# Collecting distro
#   Using cached distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->dlr==1.8.0) (1.25.11)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->dlr==1.8.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->dlr==1.8.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->dlr==1.8.0) (2020.12.5)
# Installing collected packages: distro, dlr
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/include/python3.6m/UNKNOWN
# sysconfig: /opt/conda/include/python3.6m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# Successfully installed distro-1.7.0 dlr-1.8.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import utils
import dlr

# Read the image using OpenCV
img = cv2.imread('./coco128/augmented_train/2_3-1_thermal_cropped0_jpg.rf.4bb7b8f12615790cf9a583a41f4d6f1d.jpg')
# img = cv2.imread('./coco128/images/train2017/0_1-0_thermal_cropped0')
plt.imshow(img)


#img = np.random.rand(1,3,512,512).astype(np.float32)
#plt.imshow(img)

# %%
modelDLR = dlr.DLRModel('model_object_detection', 'cpu')

def predict(model, x):
    return model.run(x)

confidence_treshold=0.1
# Convert the image to the expected network input
x = utils.preprocess_img(img, img_size=416)
# Run the model and get the predictions
preds = predict(modelDLR, x)

# Convert the predictions into Detections(bounding boxes, scores and class ids)
detections = utils.detect(preds, 0.01, 0.2, True)

print('detection.')
print(detections)

# Iterate over the detections and do what you need to do
for top_left_corner,bottom_right_corner, conf, class_id in detections:
    #if confidence_treshold < 0.1: continue
    print( f"bbox: {top_left_corner},{bottom_right_corner}, score: {conf}, class_id: {class_id}")
# Out:
# 2022-06-28 08:32:06,970 INFO Found libdlr.so in model artifact. Using dlr from model_object_detection/libdlr.so
# detection.
# [[(-25, -12), (178, 50), 0.0794057622551918, 1.0], [(-1, -7), (208, 57), 0.05563075840473175, 1.0], [(205, -19), (397, 60), 0.09535861760377884, 1.0], [(251, -28), (397, 69), 0.1595219522714615, 1.0], [(4, 0), (166, 82), 0.010843622498214245, 0.0], [(4, 0), (166, 82), 0.26842761039733887, 1.0], [(23, -12), (210, 95), 0.010040754452347755, 0.0], [(23, -12), (210, 95), 0.21227556467056274, 1.0], [(224, -6), (383, 94), 0.012419145554304123, 0.0], [(224, -6), (383, 94), 0.30395635962486267, 1.0], [(254, -9), (399, 96), 0.01873016729950905, 0.0], [(254, -9), (399, 96), 0.45904341340065, 1.0], [(-6, 30), (196, 124), 0.018894236534833908, 1.0], [(12, 39), (214, 113), 0.025693494826555252, 1.0], [(214, 16), (404, 135), 0.01656969077885151, 1.0], [(255, 42), (410, 117), 0.07368412613868713, 1.0], [(-25, 63), (191, 168), 0.0647905170917511, 1.0], [(10, 70), (205, 155), 0.044433288276195526, 1.0], [(222, 60), (395, 154), 0.03619512543082237, 1.0], [(267, 70), (398, 156), 0.01052078790962696, 0.0], [(267, 70), (398, 156), 0.27721884846687317, 1.0], [(-21, 97), (195, 178), 0.04358862712979317, 1.0]]
# bbox: (-25, -12),(178, 50), score: 0.0794057622551918, class_id: 1.0
# bbox: (-1, -7),(208, 57), score: 0.05563075840473175, class_id: 1.0
# bbox: (205, -19),(397, 60), score: 0.09535861760377884, class_id: 1.0
# bbox: (251, -28),(397, 69), score: 0.1595219522714615, class_id: 1.0
# bbox: (4, 0),(166, 82), score: 0.010843622498214245, class_id: 0.0
# bbox: (4, 0),(166, 82), score: 0.26842761039733887, class_id: 1.0
# bbox: (23, -12),(210, 95), score: 0.010040754452347755, class_id: 0.0
# bbox: (23, -12),(210, 95), score: 0.21227556467056274, class_id: 1.0
# bbox: (224, -6),(383, 94), score: 0.012419145554304123, class_id: 0.0
# bbox: (224, -6),(383, 94), score: 0.30395635962486267, class_id: 1.0
# bbox: (254, -9),(399, 96), score: 0.01873016729950905, class_id: 0.0
# bbox: (254, -9),(399, 96), score: 0.45904341340065, class_id: 1.0
# bbox: (-6, 30),(196, 124), score: 0.018894236534833908, class_id: 1.0
# bbox: (12, 39),(214, 113), score: 0.025693494826555252, class_id: 1.0
# bbox: (214, 16),(404, 135), score: 0.01656969077885151, class_id: 1.0
# bbox: (255, 42),(410, 117), score: 0.07368412613868713, class_id: 1.0
# bbox: (-25, 63),(191, 168), score: 0.0647905170917511, class_id: 1.0
# bbox: (10, 70),(205, 155), score: 0.044433288276195526, class_id: 1.0
# bbox: (222, 60),(395, 154), score: 0.03619512543082237, class_id: 1.0
# bbox: (267, 70),(398, 156), score: 0.01052078790962696, class_id: 0.0
# bbox: (267, 70),(398, 156), score: 0.27721884846687317, class_id: 1.0
# bbox: (-21, 97),(195, 178), score: 0.04358862712979317, class_id: 1.0

# %% [markdown]
# ## 7) Create a SageMaker Edge Manager packaging job
#
# Once the model has been compiled, it is time to create an edge manager packaging job. Packaging job take SageMaker Neo–compiled models and make any changes necessary to deploy the model with the inference engine, Edge Manager agent.
#
# We need to provide the name used for the Neo compilation job, a name for the packaging job, a role ARN, a name for the model, a model version, and the Amazon S3 bucket URI for the output of the packaging job. Note that Edge Manager packaging job names are case-sensitive.
#
#
# The below cell also calls the `describe_edge_packaging_job` API in a loop to wait for the packaging job to complete. In actual applications, it is advisable to setup a cloudwatch event which can notify OR execute the next steps once the compilation job is complete.

# %%
import time
model_version = '1.0'
edge_packaging_job_name=f'{model_name}-pytorch-{int(time.time()*1000)}'
resp = sm_client.create_edge_packaging_job(
    EdgePackagingJobName=edge_packaging_job_name,
    CompilationJobName=compilation_job_name,
    ModelName=model_name,
    ModelVersion=model_version,
    RoleArn=role,
    OutputConfig={
        'S3OutputLocation': f's3://{bucket_name}/{model_name}'
    }
)
while True:
    resp = sm_client.describe_edge_packaging_job(EdgePackagingJobName=edge_packaging_job_name)    
    if resp['EdgePackagingJobStatus'] in ['STARTING', 'INPROGRESS']:
        print('Running...')
    else:
        print(resp['EdgePackagingJobStatus'], compilation_job_name)
        print('package s3 location: ' + 's3://'+bucket_name+'/'+model_name)
        break
    time.sleep(5)

# %% [markdown]
# ## 6) Pre processing + Post processing code
# After compiling your model, it's time to prepare the application that will use it. In the image bellow you can see the operators that are used by the last layer **YOLOLayer**. When in evaluation mode, this layer applies some operations to merge the two outputs of the network and prepare the predictions for the **Non Maximum Suppression**. In training model, you just have the two raw outputs.
#
# Given we're using a pruned version (training mode) of the network, you need to apply some post processing code to your predictions.
#
# <table style="border: 1px solid black; border-collapse: collapse;" border=3 cellpadding=0 cellspacing=0>
#     <tr style="border: 1px solid black;">
#         <td style="text-align: center; border-right: 1px solid;" align="center"><b>WITH DETECTION (evaluation mode)</b></td>
#         <td style="text-align: center;" align="center"><b>NO DETECTION (training mode)</b></td>
#     </tr>
#     <tr style="border: 1px solid black; border-right: 1px solid;">
#         <td width="75%" style="border-right: 1px solid;">
#             <img src="imgs/yolov4_detection.png"/>
#         </td>
#         <td>
#             <img src="imgs/yolov4_no_detection.png"/>
#         </td>
#     </tr>
# </table>
#
# All the operations required by this process can be found in the script **[Utils](utils.py)**.
# #### WARNING: run the next cell and copy the output to your **utils.py** before running the application. It is necessary to adjust the anchors and scores for the correct yolov4 version
#
#
# Here it is an example of how to use the code:
# ```Python
# import utils
#
# ### your code here
# ### def predict(model, x):...
#
# confidence_treshold=0.1
# # Read the image using OpenCV
# img = cv2.imread('dog.jpg')
# # Convert the image to the expected network input
# x = utils.preprocess_img(img, img_size=416)
# # Run the model and get the predictions
# preds = model(x)
# # Convert the predictions into Detections(bounding boxes, scores and class ids)
# detections = utils.detect(preds, 0.25, 0.5, True)
# # Iterate over the detections and do what you need to do
# for top_left_corner,bottom_right_corner, conf, class_id in detections:
#     if confidence_treshold < 0.1: continue
#     print( f"bbox: {top_left_corner},{bottom_right_corner}, score: {conf}, class_id: {class_id}")
# ```

# %%
# This code parses the .cfg file of the version you're using and
## Prints the correct anchors/stride. Copy the output to the 'utils.py' file used by your application
import numpy as np

cfg_filename=f'yolov4/cfg/{model_name}.cfg'
yolo_layer=False
yolo_layers = []

for i in open(cfg_filename, 'r').readlines(): # read the .cfg file
    i = i.strip()
    if len(i) == 0 or i.startswith('#'): continue # ignore empty lines and comments
    elif i.startswith('[') and i.endswith(']'): # header
        if i.lower().replace(' ', '') == '[yolo]':
            yolo_layer = True # yolo layer
            yolo_layers.append({})
    elif yolo_layer: # properties of the layer
        k,v = [a.strip() for a in i.split('=')] # split line into key, value
        if k == 'anchors': # parse anchors
            anchors = np.array([int(j.strip()) for j in v.split(',')])
            yolo_layers[-1]['anchors'] = anchors.reshape((len(anchors)//2, 2))
        elif k == 'mask': # parse mask
            yolo_layers[-1]['mask'] = np.array([int(j.strip()) for j in v.split(',')])

stride = [8, 16, 32, 64, 128]  # P3, P4, P5, P6, P7 strides
if model_type == 'tiny':  # P5, P4, P3 strides
    stride = [32, 16, 8]

print("##### Copy the following lines to your util.py")
print(f"anchors = {[l['anchors'][l['mask']].tolist() for l in yolo_layers]}")
print(f"stride = {stride}")

# %% [markdown]
# ### Done !!
#
# And we are done with all the steps needed to prepare the model for deploying to edge. The model package is avaialble in S3 and can be taken from there to deploy it to edge device. Now you need to move over to your edge device and download and setup edge manager agent(runtime), model and other related artifacts on the device. Please check out the [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/edge.html) for detailed steps.

# %% [markdown]
# ## 7) Setup Edge Manager Server
# ### 7.1) First you need to prepare and run a Cloudformation template to create the infrastructure required for running the Edge Manager
# Run the next cell, click on the link it will create and don't forget to ack the capability in the Cloudformation screen

# %%
import boto3
import sagemaker
from IPython import display

s3_client = boto3.client('s3')
sts_client = boto3.client('sts')

session = boto3.session.Session()
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
region = session.region_name
bucket_name = sagemaker_session.default_bucket()
account_id = sts_client.get_caller_identity()["Account"]

stack_name='experiments'
fleet_name=f'micro-device-fleet-{stack_name}'
device_name=f'device0-micro-device-fleet-{stack_name}'
policy_name=f'MicroDeviceFleetPolicy-{stack_name}'
iot_policy_name=f'SageMakerEdge-micro-device-fleet-{stack_name}'

template_url=f'https://s3.amazonaws.com/spock.cloud/ml-edge/micro-device-fleet.yml'
template_params={
    'stackName': stack_name,
    'param_BucketName': bucket_name,
    'param_SageMakerRoleArn': role
}
params = "&".join([f"{k}={v}" for k,v in template_params.items()])
cfn_quick_link=f"https://{region}.console.aws.amazon.com/cloudformation/home?region={region}#/stacks/create/review?templateURL={template_url}&{params}"

display.HTML(f'<a href="{cfn_quick_link}"> >>> Click <strong>here</strong> to launch the Cloudformation Stack, but don\'t forget to ack the following capability << </a> ')

# %% [markdown]
# ## 7.2) Install some dependencies

# %%
# !apt-get -y update && apt-get -y install build-essential procps
# !pip install -U numpy sysv_ipc boto3 grpcio-tools grpcio protobuf sagemaker

# %%
## 7.3) Download and prepare the SageMaker Edge Agent

# %%
### 7.3.1) Download/unpack the agent for X86_64

# %%
import boto3
import sagemaker
import os
import tarfile
import io
import stat

sm_client = boto3.client('sagemaker')

agent_version = '1.20210820.e20fa3a'
agent_pkg_bucket = 'sagemaker-edge-release-store-us-west-2-linux-x64'

if not os.path.isdir('agent'):
    s3_client = boto3.client('s3')

    # Download and install SageMaker Edge Manager
    agent_pkg_key = f'Releases/{agent_version}/{agent_version}.tgz'
    # get the agent package
    with io.BytesIO() as file:
        s3_client.download_fileobj(agent_pkg_bucket, agent_pkg_key, file)
        file.seek(0)
        # Extract the files
        tar = tarfile.open(fileobj=file)
        tar.extractall('agent')
        tar.close()
        # Adjust the permissions
        os.chmod('agent/bin/sagemaker_edge_agent_binary', stat.S_IXUSR|stat.S_IWUSR|stat.S_IXGRP|stat.S_IWGRP)
    
    # by using protoc, we can generate stubs (client api) for connecting to the agent and invoking its API
    if not os.path.isdir('app'): os.mkdir('app')
    # !python3 -m grpc_tools.protoc --proto_path=agent/docs/api --python_out=app/ --grpc_python_out=app/ agent/docs/api/agent.proto

# %%
### 7.3.2) Create the certificates if needed
These are IoT certificates, used by the agent to communicate with the cloud when needed: to send heartbeats and or capture data

# %%
import urllib.request

cert_root_dir=os.path.join('agent', 'certificates', 'root')
cert_iot_dir=os.path.join('agent', 'certificates', 'iot')
if not os.path.isdir(cert_root_dir): os.makedirs(cert_root_dir)
if not os.path.isdir(cert_iot_dir): os.makedirs(cert_iot_dir)

# assume a different role (created by the CFN you executed at the beginning for IoT ops)
role_arn = f"arn:aws:iam::{account_id}:role/MicroDeviceFleetRole-{stack_name}"
temp_role = boto3.client('sts').assume_role(RoleArn=role_arn, RoleSessionName="MicroDeviceFleetSession2")
credentials = temp_role['Credentials']

iot_client = boto3.client(
    'iot',
    aws_access_key_id=credentials['AccessKeyId'],
    aws_secret_access_key=credentials['SecretAccessKey'],
    aws_session_token=credentials['SessionToken']
)

if not os.path.isfile(os.path.join(cert_iot_dir, 'device0_key.pem')):
    print('Creating a new certificate')
    cert_meta = iot_client.create_keys_and_certificate(setAsActive=True)
    cert_arn = cert_meta['certificateArn']
    # attach the certificates to the policy and to the thing
    iot_client.attach_policy(policyName=policy_name, target=cert_arn)
    
    with open(os.path.join(cert_iot_dir, 'device0_cert.pem'), 'w') as c: c.write(cert_meta['certificatePem'])
    with open(os.path.join(cert_iot_dir, 'device0_key.pem'),  'w') as c: c.write(cert_meta['keyPair']['PrivateKey'])
    with open(os.path.join(cert_iot_dir, 'device0_pub.pem'),  'w') as c: c.write(cert_meta['keyPair']['PublicKey'])
    
    # get root certs
    urllib.request.urlretrieve('https://www.amazontrust.com/repository/AmazonRootCA1.pem', os.path.join(cert_root_dir, 'AmazonRootCA1.pem'))
    # this certificate validates the edge manage package
    s3_client.download_file(
        Bucket=agent_pkg_bucket, 
        Key=f'Certificates/{region}/{region}.pem', 
        Filename=os.path.join(cert_root_dir, f"{region}.pem")
    )        
    # adjust the permissions of the files
    os.chmod(os.path.join(cert_root_dir, 'AmazonRootCA1.pem'), stat.S_IRUSR|stat.S_IRGRP)
    os.chmod(os.path.join(cert_root_dir, f"{region}.pem"), stat.S_IRUSR|stat.S_IRGRP)

# %% [markdown]
# ### 7.3.3) Create the Agent config file

# %%
import json
cred_host=iot_client.describe_endpoint(endpointType='iot:CredentialProvider')['endpointAddress']
agent_params = {
    "sagemaker_edge_core_device_name": device_name,
    "sagemaker_edge_core_device_fleet_name": fleet_name,
    "sagemaker_edge_core_capture_data_buffer_size": 30,
    "sagemaker_edge_core_capture_data_batch_size": 10,
    "sagemaker_edge_core_capture_data_push_period_seconds": 4,
    "sagemaker_edge_core_folder_prefix": "micro-device-fleet-data",
    "sagemaker_edge_core_region": region,
    "sagemaker_edge_core_root_certs_path": "./agent/certificates/root",
    "sagemaker_edge_provider_aws_ca_cert_file":"./agent/certificates/root/AmazonRootCA1.pem",
    "sagemaker_edge_provider_aws_cert_file": os.path.join(".", cert_iot_dir, 'device0_cert.pem'),
    "sagemaker_edge_provider_aws_cert_pk_file":os.path.join(".", cert_iot_dir, 'device0_key.pem'),
    "sagemaker_edge_provider_aws_iot_cred_endpoint": f"https://{cred_host}/role-aliases/{iot_policy_name}/credentials",
    "sagemaker_edge_provider_provider": "Aws",
    "sagemaker_edge_provider_provider_path" : os.path.abspath("./agent/lib/libprovider_aws.so"),
    "sagemaker_edge_provider_s3_bucket_name": bucket_name,
    "sagemaker_edge_core_capture_data_destination": "Cloud"
}
conf_dir = os.path.join('agent', 'conf')
conf_file_name='config_edge_device0.json'
if not os.path.isdir(conf_dir): os.makedirs(conf_dir)
with open(os.path.join(conf_dir, conf_file_name), 'w') as conf:
    conf_file = json.dumps(agent_params, indent=4)
    conf.write(conf_file)
    print(conf_file)

# %%
## 8) Run the agent in background
The agent is a simple application that will run on your OS. Let's use subprocess to create a background process with the agent

# %%
import subprocess
import time
channel_path='/tmp/agent_dev'
if os.path.exists(channel_path): os.remove(channel_path)
cmd = f'./agent/bin/sagemaker_edge_agent_binary -c agent/conf/{conf_file_name} -a {channel_path}'
print(cmd)
if not os.path.exists('agent/logs'): os.makedirs('agent/logs')
logs = open("agent/logs/agent0.log", "+w")
proc = subprocess.Popen(cmd.split(' '), stdout=logs)
time.sleep(2)
# !ps aux --cols 300|grep sagemaker_edge_agent

# %% [markdown]
# ## 9) Test the model, using SageMaker Edge Agent

# %%
import sys
sys.path.insert(1, 'app')
import numpy as np
import grpc

# Loading the stubs - agent python client
import agent_pb2 as agent
import agent_pb2_grpc as agent_grpc
import edge_agent_utils as edge

# %%
# Connecting to the agent
channel = grpc.insecure_channel(f'unix://{channel_path}' )
client = agent_grpc.AgentStub(channel)

# %%
model_alias='image-classification'

## Loading a model in the agent
edge.load_model(client, model_alias, model_path)

# %%
### Validate the model with a an image

# %%
quick and dirty parser for the labels
labels = {}
for l in open('labels.txt', 'r').read().splitlines():
    l = l.strip().replace('{', '').replace('}', '')
    l = l[:-1] if l.endswith(',') else l
    cls_id,label = [t.strip() for t in l.split(':')]
    labels[int(cls_id)] = label[1:-1] # remove the single quotes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
img_size=224
# load the image and make it squared if needed
img = cv2.cvtColor(cv2.imread('cat.jpg'), cv2.COLOR_BGR2RGB)
h,w,c = img.shape
if w!=h: # pad the image and make it square
    sqr_size = max(h,w)
    sqr_img = np.zeros((sqr_size, sqr_size, c), dtype=np.uint8)
    sqr_img[:h, :w],img = img,sqr_img
# resize the image to the expected size+transform it to pytorch/imagenet format
x = cv2.resize(img, (img_size, img_size)).astype(np.float32) / 255.0
# normalize
x -= [0.485, 0.456, 0.406]
x /= [0.229, 0.224, 0.225]
x = x.transpose(2,0,1) # HWC --> CHW
c,h,w = x.shape
x = x.reshape(1,c,h,w) # CHW --> NCHW

# %%
y = edge.predict(client, model_alias, x)
idx = np.argmax(y)
print(f"Class id: {idx}, Score: {y[0][idx]}, Label: {labels[idx]}")
plt.imshow(img)

# %% [markdown]
# ### Done, you can stop the agent now

# %%
# stop the agent
proc.kill()
